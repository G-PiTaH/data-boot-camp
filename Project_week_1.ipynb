# %% [markdown]
# <a href="https://colab.research.google.com/github/G-PiTaH/data-boot-camp/blob/main/Project_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
! kaggle datasets download ayushmi77al/weather-data-set-for-beginners
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ayushmi77al/weather-data-set-for-beginners
# License(s): unknown
# ...
#   0% 0.00/101k [00:00<?, ?B/s]
# 100% 101k/101k [00:00<00:00, 8.03MB/s]

# %%
# !unzip /content/weather-data-set-for-beginners.zip
# Out:
# Archive:  /content/weather-data-set-for-beginners.zip
#   inflating: 1. Weather Data.csv

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("1. Weather Data.csv")

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
data.shape
# Out:
# (8784, 8)

# %% [markdown]
# All records where the weather was exactly clear

# %%
weather_clear  =  data[data['Weather'] == 'Clear']

# %%
weather_clear.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
weather_clear.tail(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# 8714           25.0     101.33   Clear
# 8756           25.0     101.52   Clear

# %%
weather_clear.shape
# Out:
# (1326, 8)

# %% [markdown]
# Number of times the wind speed was exactly 4 km/hr.

# %%
wind_speed  =  data[data['Wind Speed_km/h'] == 4]

# %%
wind_speed.shape[0]
# Out:
# 474

# %% [markdown]
# NULL values present in the dataset

# %%
null_values = data.isnull()

# %%
null_values.sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Column "Weather" to "Weather_Condition"

# %%
data.rename(columns = {'Weather': 'Weather_Condition'}, inplace = True)

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
#  Mean visibility of the dataset

# %%
mean_visibility = data['Visibility_km']

# %%
mean_visibility.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# Where the wind speed is greater than 24 km/hr and visibility is equal to 25 km

# %%
wind_visibility = data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]

# %%
wind_visibility.shape[0]
# Out:
# 308

# %% [markdown]
# Mean value of each column for each weather condition

# %%
mean_by_weather = data.groupby('Weather_Condition')

# %%
mean_by_weather.dtypes
# Out:
# <ipython-input-62-07cfff5db182>:1: FutureWarning: DataFrameGroupBy.dtypes is deprecated and will be removed in a future version. Check the dtypes on the base object instead
#   mean_by_weather.dtypes
#                                         Date/Time   Temp_C Dew Point Temp_C  \
# Weather_Condition
# Clear                                      object  float64          float64
# Cloudy                                     object  float64          float64
# Drizzle                                    object  float64          float64
# Drizzle,Fog                                object  float64          float64
# Drizzle,Ice Pellets,Fog                    object  float64          float64
# Drizzle,Snow                               object  float64          float64
# Drizzle,Snow,Fog                           object  float64          float64
# Fog                                        object  float64          float64
# ...

# %%
data['Weather_Condition'] = pd.to_numeric(data['Weather_Condition'], errors='coerce')

# %%
mean_by_weather = data.groupby('Weather_Condition')

# %%
mean_by_weather.mean()
# Out:
# Date/Time           NaN
# Temp_C              NaN
# Dew Point Temp_C    NaN
# Rel Hum_%           NaN
# Wind Speed_km/h     NaN
# Visibility_km       NaN
# Press_kPa           NaN
# dtype: object

# %% [markdown]
# Instances where the weather is clear and the relative humidity is greater than 50, or visibility is above 40

# %%
weather_filtred = data[(data['Weather_Condition'] == 'Clear') & (data['Rel Hum_%'] > 50) | (data['Visibility_km'] > 40) ]

# %%
weather_filtred.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
# 110  1/5/2012 14:00    -5.1             -10.7         65               22
#
#      Visibility_km  Press_kPa  Weather_Condition
# 106           48.3     100.45                NaN
# 107           48.3     100.41                NaN
# 108           48.3     100.38                NaN
# 109           48.3     100.40                NaN
# 110           48.3     100.46                NaN

# %% [markdown]
# Number of weather conditions that include snow

# %%
conditions = data[data['Weather_Condition'].str.contains('Snow')]['Weather_Condition'].nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-539c60408c04> in <cell line: 1>()
# ----> 1 conditions = data[data['Weather_Condition'].str.contains('Snow')]['Weather_Condition'].nunique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...
